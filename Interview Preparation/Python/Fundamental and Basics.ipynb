# %% [markdown]
# Q1. What is Python, and what are its key features?
#
# Python is a high-level, interpreted, dynamically typed, object-oriented, and general-purpose programming language. It is known for its simple and readable syntax, which makes development faster and easier.
# Python has a large standard library and a vast ecosystem.
# It is widely used in web development, automation, data analysis, machine learning, artificial intelligence.
#
# -----------------------------------------------
#
# High-level → Easy for humans to read and write.
# Interpreted → Code is executed line by line without prior compilation.
# Dynamically typed → No need to declare variable types explicitly; Python determines them at runtime.
# Object-oriented → Supports programming using classes and objects.
# General-purpose → Can be used in many domains, not limited to a specific type of application.
#
# -----------------------------------------------
#
# Q2. What are the advantages and disadvantages of Python?
# Python's biggest strengths are its simplicity, rich ecosystem, and rapid development, while its main limitations are slower execution speed and higher memory usage compared to compiled languages.
#
# -----------------------------------------------
#
#
# Q3. What is the difference between a compiled language and an interpreted language? Where
# does Python fit?
#
# A compiled language converts the entire source code into machine code before execution, producing an executable file. This generally results in faster execution.
#
# An interpreted language executes the source code line by line at runtime without creating a separate executable, making it easier to debug but generally slower.
#
# -----------------------------------------------
#
# Q4. What are Python keywords? How do they differ from identifiers?
#
# Keywords are reserved words in Python that have predefined meanings and are used to define the language's syntax and structure.
# They cannot be used as variable, function, or class names.
#
# Identifiers are user-defined names given to variables, functions, classes, modules, etc.
# They must follow Python's naming rules and cannot be Python keywor
#
# -----------------------------------------------
#
# Q5. What are variables in Python? Are they strongly typed or dynamically typed?
#
# A variable in Python is a name that refers to an object/value stored in memory. Python is dynamically typed, meaning you do not need to declare a variable's data type explicitly
# However, Python is also strongly typed, meaning it does not perform unsafe implicit type conversions between incompatible types.
#
# -----------------------------------------------
#
# Q7. Explain the difference between mutable and immutable objects ?
#
# In Python, mutable objects can be modified after they are created, whereas immutable objects cannot be changed once created.
# Any modification to an immutable object creates a new object instead of changing the existing one.
#
# Mutable: list , dict ,set
#
# Immutable: int,float,str,tuple
#
# Q8. Which Python data types are mutable, and which are immutable?
# ans: last ques

# %%
"""
Q9. What is the difference between is and ==? 
object: Think of an object as the actual data stored in memory, while a variable is just a name (reference) that points to that data.

In Python, == ( equality op ) checks whether two objects have the same value, while is ( identity op ) checks whether two variables refer to the exact same object in memory.
"""
a=[1,2]
b=[1,2]
print(f"is a==b? = {a==b}")
print(f" a is b ? {a is b}")
print(id(a))
print(id(b))
# Out:
# is a==b? = True
#  a is b ? False
# 2945687772224
# 2945687718592

# %%
"""
Q11. What is the difference between a List and a Tuple? 

A List is a mutable, ordered collection, whereas a Tuple is an immutable, ordered collection.
Lists are used when data needs to change, while tuples are used for fixed data. 

"""
# list:
a=[1,2,3]
print(id(a))
a.append(4)
a[0]=0
print(a)
print(id(a))
print('-------------------------------------------')

# for tuple
name=('ved','prakash')
print(id(name))
print(name[0])
name[0]='abhi'
print(name)
# Out:
# 2945694419520
# [0, 2, 3, 4]
# 2945694419520
# -------------------------------------------
# 2945694530176
# ved
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 21
#      19 print(id(name))
#      20 print(name[0])
# ---> 21 name[0]='abhi'
#      22 print(name)
#
# TypeError: 'tuple' object does not support item assignment

# %%
"""   
Q12. What is the difference between a List and a Set?  
A List is an ordered, mutable collection that allows duplicate elements,
hereas a Set is an unordered, mutable collection that stores only unique elements.

List → Ordered + Duplicates Allowed
Set → Unordered + Unique Elements Only
"""

x=[1,1,2,3,3]
print(f" for list : {x}") # ordered
x.append(4)
print( f" for list index at o {x[0]}")

y={1,1,1,2,3,4,4}
print(f"for set that shows only unique value {y}") # only unique value
print(y[0])
# Out:
#  for list : [1, 1, 2, 3, 3]
#  for list index at o 1
# for set that shows only unique value {1, 2, 3, 4}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 17
#      15 y={1,1,1,2,3,4,4}
#      16 print(f"for set that shows only unique value {y}") # only unique value
# ---> 17 print(y[0])
#
# TypeError: 'set' object is not subscriptable

# %%
"""   
Q13. What is the difference between a Dictionary and a List? 
A List stores elements in an ordered sequence and accesses them using integer indexes,
whereas a Dictionary stores data as key-value pairs and accesses values using unique keys.

List → Index-based collection.
Dictionary → Key-value based collection.

Dictionary keys must be immutable because dictionaries use a hash table for fast lookups.
An immutable key has a constant hash value, ensuring the dictionary can always locate the correct key efficiently.
"""
details={"age": 23, "name":"ved"} # dict
print(details['age'])


"""   
Q19. What is the difference between int(), float(), str(), list(), and tuple()?
 These are built-in type conversion functions used to convert values into different data types. 
"""
# Out:
# 23

# %%
"""
Q20. Predict the output of a program that performs arithmetic operations between integers and
floating-point numbers. 
   
"""
x=5
y=5.0
z=x+y
print(z)
print(type(z))
# Out:
# 10.0
# <class 'float'>
