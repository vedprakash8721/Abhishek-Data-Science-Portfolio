# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# %%
# ------------------------------- CONVERTING OBJECT TO INT/FLOAT AS COLUMN SHOULD BE -------------------------------
df=pd.read_csv('kidney_disease.csv')
display(df.head(5))
display(df.columns)
df.drop('id',axis=1,inplace=True)
df.columns=[
'Age (years)',
'Blood Pressure (mm/Hg)',
'Specific Gravity (urine)',
'Albumin (urine)',
'Sugar (urine)',
'Red Blood Cells (urine)',
'Pus Cell (urine)',
'Pus Cell Clumps',
'Bacteria (urine)',
'Blood Glucose Random (mg/dL)',
'Blood Urea (mg/dL)',
'Serum Creatinine (mg/dL)',
'Sodium (mEq/L)',
'Potassium (mEq/L)',
'Hemoglobin (g/dL)',
'Packed Cell Volume (%)',
'White Blood Cell Count (cells/cumm)',
'Red Blood Cell Count (millions/cumm)',
'Hypertension',
'Diabetes Mellitus',
'Coronary Artery Disease',
'Appetite',
'Pedal Edema',
'Anemia',
'Chronic Kidney Disease Classification'
]
display(df.columns)
display(df.head(5))
display(df['Serum Creatinine (mg/dL)'].sort_values(ascending=False)[:10])
display(df.shape)
display(df.describe())
display(df.info())
display(df['Red Blood Cells (urine)'])
display(df['Pus Cell (urine)'])
display(df['Bacteria (urine)'])
display(df['Packed Cell Volume (%)'].unique())
df['Packed Cell Volume (%)']=pd.to_numeric(df['Packed Cell Volume (%)'],errors='coerce')
display(df['Packed Cell Volume (%)'].dtypes)
df['White Blood Cell Count (cells/cumm)']=pd.to_numeric(df['White Blood Cell Count (cells/cumm)'],errors='coerce')
df['Red Blood Cell Count (millions/cumm)']=pd.to_numeric(df['Red Blood Cell Count (millions/cumm)'],errors='coerce')
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')
# Index(['Age (years)', 'Blood Pressure (mm/Hg)', 'Specific Gravity (urine)',
#        'Albumin (urine)', 'Sugar (urine)', 'Red Blood Cells (urine)',
#        'Pus Cell (urine)', 'Pus Cell Clumps', 'Bacteria (urine)',
#        'Blood Glucose Random (mg/dL)', 'Blood Urea (mg/dL)',
#        'Serum Creatinine (mg/dL)', 'Sodium (mEq/L)', 'Potassium (mEq/L)',
#        'Hemoglobin (g/dL)', 'Packed Cell Volume (%)',
#        'White Blood Cell Count (cells/cumm)',
#        'Red Blood Cell Count (millions/cumm)', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Chronic Kidney Disease Classification'],
#       dtype='object')
#    Age (years)  Blood Pressure (mm/Hg)  Specific Gravity (urine)  \
# 0         48.0                    80.0                     1.020
# 1          7.0                    50.0                     1.020
# 2         62.0                    80.0                     1.010
# 3         48.0                    70.0                     1.005
# 4         51.0                    80.0                     1.010
#
#    Albumin (urine)  Sugar (urine) Red Blood Cells (urine) Pus Cell (urine)  \
# 0              1.0            0.0                     NaN           normal
# 1              4.0            0.0                     NaN           normal
# 2              2.0            3.0                  normal           normal
# 3              4.0            0.0                  normal         abnormal
# 4              2.0            0.0                  normal           normal
#
#   Pus Cell Clumps Bacteria (urine)  Blood Glucose Random (mg/dL)  ...  \
# 0      notpresent       notpresent                         121.0  ...
# 1      notpresent       notpresent                           NaN  ...
# 2      notpresent       notpresent                         423.0  ...
# 3         present       notpresent                         117.0  ...
# 4      notpresent       notpresent                         106.0  ...
#
#    Packed Cell Volume (%)  White Blood Cell Count (cells/cumm)  \
# 0                      44                                 7800
# 1                      38                                 6000
# 2                      31                                 7500
# 3                      32                                 6700
# 4                      35                                 7300
#
#    Red Blood Cell Count (millions/cumm)  Hypertension  Diabetes Mellitus  \
# 0                                   5.2           yes                yes
# 1                                   NaN            no                 no
# 2                                   NaN            no                yes
# 3                                   3.9           yes                 no
# 4                                   4.6            no                 no
#
#   Coronary Artery Disease Appetite Pedal Edema Anemia  \
# 0                      no     good          no     no
# 1                      no     good          no     no
# 2                      no     poor          no    yes
# 3                      no     poor         yes    yes
# 4                      no     good          no     no
#
#   Chronic Kidney Disease Classification
# 0                                   ckd
# 1                                   ckd
# 2                                   ckd
# 3                                   ckd
# 4                                   ckd
#
# [5 rows x 25 columns]
# 21     76.0
# 148    48.1
# 61     32.0
# 6      24.0
# 193    18.1
# 143    18.0
# 134    16.9
# 154    16.4
# 246    15.2
# 84     15.0
# Name: Serum Creatinine (mg/dL), dtype: float64
# (400, 25)
#        Age (years)  Blood Pressure (mm/Hg)  Specific Gravity (urine)  \
# count   391.000000              388.000000                353.000000
# mean     51.483376               76.469072                  1.017408
# std      17.169714               13.683637                  0.005717
# min       2.000000               50.000000                  1.005000
# 25%      42.000000               70.000000                  1.010000
# 50%      55.000000               80.000000                  1.020000
# 75%      64.500000               80.000000                  1.020000
# max      90.000000              180.000000                  1.025000
#
#        Albumin (urine)  Sugar (urine)  Blood Glucose Random (mg/dL)  \
# count       354.000000     351.000000                    356.000000
# mean          1.016949       0.450142                    148.036517
# std           1.352679       1.099191                     79.281714
# min           0.000000       0.000000                     22.000000
# 25%           0.000000       0.000000                     99.000000
# 50%           0.000000       0.000000                    121.000000
# 75%           2.000000       0.000000                    163.000000
# max           5.000000       5.000000                    490.000000
#
#        Blood Urea (mg/dL)  Serum Creatinine (mg/dL)  Sodium (mEq/L)  \
# count          381.000000                383.000000      313.000000
# mean            57.425722                  3.072454      137.528754
# std             50.503006                  5.741126       10.408752
# min              1.500000                  0.400000        4.500000
# 25%             27.000000                  0.900000      135.000000
# 50%             42.000000                  1.300000      138.000000
# 75%             66.000000                  2.800000      142.000000
# max            391.000000                 76.000000      163.000000
#
#        Potassium (mEq/L)  Hemoglobin (g/dL)
# count         312.000000         348.000000
# mean            4.627244          12.526437
# std             3.193904           2.912587
# min             2.500000           3.100000
# 25%             3.800000          10.300000
# 50%             4.400000          12.650000
# 75%             4.900000          15.000000
# max            47.000000          17.800000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Age (years)                            391 non-null    float64
#  1   Blood Pressure (mm/Hg)                 388 non-null    float64
#  2   Specific Gravity (urine)               353 non-null    float64
#  3   Albumin (urine)                        354 non-null    float64
#  4   Sugar (urine)                          351 non-null    float64
#  5   Red Blood Cells (urine)                248 non-null    object
#  6   Pus Cell (urine)                       335 non-null    object
#  7   Pus Cell Clumps                        396 non-null    object
#  8   Bacteria (urine)                       396 non-null    object
#  9   Blood Glucose Random (mg/dL)           356 non-null    float64
#  10  Blood Urea (mg/dL)                     381 non-null    float64
#  11  Serum Creatinine (mg/dL)               383 non-null    float64
#  12  Sodium (mEq/L)                         313 non-null    float64
#  13  Potassium (mEq/L)                      312 non-null    float64
#  14  Hemoglobin (g/dL)                      348 non-null    float64
#  15  Packed Cell Volume (%)                 330 non-null    object
#  16  White Blood Cell Count (cells/cumm)    295 non-null    object
#  17  Red Blood Cell Count (millions/cumm)   270 non-null    object
#  18  Hypertension                           398 non-null    object
#  19  Diabetes Mellitus                      398 non-null    object
#  20  Coronary Artery Disease                398 non-null    object
#  21  Appetite                               399 non-null    object
#  22  Pedal Edema                            399 non-null    object
#  23  Anemia                                 399 non-null    object
#  24  Chronic Kidney Disease Classification  400 non-null    object
# dtypes: float64(11), object(14)
# memory usage: 78.3+ KB
# None
# 0         NaN
# 1         NaN
# 2      normal
# 3      normal
# 4      normal
#         ...
# 395    normal
# 396    normal
# 397    normal
# 398    normal
# 399    normal
# Name: Red Blood Cells (urine), Length: 400, dtype: object
# 0        normal
# 1        normal
# 2        normal
# 3      abnormal
# 4        normal
#          ...
# 395      normal
# 396      normal
# 397      normal
# 398      normal
# 399      normal
# Name: Pus Cell (urine), Length: 400, dtype: object
# 0      notpresent
# 1      notpresent
# 2      notpresent
# 3      notpresent
# 4      notpresent
#           ...
# 395    notpresent
# 396    notpresent
# 397    notpresent
# 398    notpresent
# 399    notpresent
# Name: Bacteria (urine), Length: 400, dtype: object
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)
# dtype('float64')

# %%
display(df.columns)
display(df['Chronic Kidney Disease Classification'].unique())
df['Chronic Kidney Disease Classification']=df['Chronic Kidney Disease Classification'].str.strip()
# Out:
# Index(['Age (years)', 'Blood Pressure (mm/Hg)', 'Specific Gravity (urine)',
#        'Albumin (urine)', 'Sugar (urine)', 'Red Blood Cells (urine)',
#        'Pus Cell (urine)', 'Pus Cell Clumps', 'Bacteria (urine)',
#        'Blood Glucose Random (mg/dL)', 'Blood Urea (mg/dL)',
#        'Serum Creatinine (mg/dL)', 'Sodium (mEq/L)', 'Potassium (mEq/L)',
#        'Hemoglobin (g/dL)', 'Packed Cell Volume (%)',
#        'White Blood Cell Count (cells/cumm)',
#        'Red Blood Cell Count (millions/cumm)', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Chronic Kidney Disease Classification'],
#       dtype='object')
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
# ------------------------------ VISUALIZATION ------------------------------------
plt.figure(figsize=(14,6))
sns.countplot(x='Chronic Kidney Disease Classification',data=df,palette={'ckd':'red','notckd':'green'})
plt.show()

# %%
# separating the categorical and numerical column
cat_col=[col for col in df.columns if df[col].dtype=='object']
num_col=[col for col in df.columns if df[col].dtype!='object']
display(cat_col)
display(num_col)
plt.figure(figsize=(14,6))
sns.bar
plot(x='Chronic Kidney Disease Classification',y='Hypertension',data=df)
plt.show()
# Out:
# ['Red Blood Cells (urine)',
#  'Pus Cell (urine)',
#  'Pus Cell Clumps',
#  'Bacteria (urine)',
#  'Hypertension',
#  'Diabetes Mellitus',
#  'Coronary Artery Disease',
#  'Appetite',
#  'Pedal Edema',
#  'Anemia',
#  'Chronic Kidney Disease Classification']
# ['Age (years)',
#  'Blood Pressure (mm/Hg)',
#  'Specific Gravity (urine)',
#  'Albumin (urine)',
#  'Sugar (urine)',
#  'Blood Glucose Random (mg/dL)',
#  'Blood Urea (mg/dL)',
#  'Serum Creatinine (mg/dL)',
#  'Sodium (mEq/L)',
#  'Potassium (mEq/L)',
#  'Hemoglobin (g/dL)',
#  'Packed Cell Volume (%)',
#  'White Blood Cell Count (cells/cumm)',
#  'Red Blood Cell Count (millions/cumm)']
