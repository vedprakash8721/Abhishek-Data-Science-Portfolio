# %% [markdown]
# What is XGBoost?
#
# XGBoost is an optimized gradient boosting algorithm that builds trees sequentially to minimize prediction errors while using regularization to improve performance and reduce overfitting.
#
# Why was XGBoost introduced?
#
#
# Gradient Boosting had some limitations:
#
# Slow training
# Can overfit
#
# XGBoost solves these problems by adding:
#
# Regularization
# Parallel processing
#
# | Gradient Boosting    | XGBoost                       |
# | -------------------- | ----------------------------- |
# | Learns residuals     | Learns residuals              |
# | No regularization    | Regularization (L1 & L2)      |
# | Slower               | Faster                        |
# | Can overfit          | Better control of overfitting |
# | Basic implementation | Highly optimized              |
#
# XGBoost = Gradient Boosting + Speed + Regularization + Optimization
#
#
# subsample
# Controls rows
# Lower value → Less overfitting
# Recommended → 0.8
#
#
# colsample_bytree
# Controls columns/features
# Lower value → Less overfitting
# Recommended → 0.8

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import xgboost
from xgboost import XGBClassifier
from sklearn.datasets import make_classification

# %%
x,y =make_classification(n_samples=1000,n_features=10,n_classes=2,random_state=42)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
xg=XGBClassifier()
param_grid={
    'n_estimators':[30,50],
    'max_depth':[3,5],
    'learning_rate':[0.1,0.2,0.002],
    # 'subsample':[0.8,1],
    # 'colsample_bytree':[0.8,1],
    'reg_alpha':[0,0.1,0.5],
    'reg_lambda':[0.5,1]
}
model=GridSearchCV(estimator=xg,param_grid=param_grid,cv=3,verbose=2)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print(f"accuracy under xgboost with hyperparameter tuning  = {acc}")
print(f"classification_report = {classification_report(y_test,y_pred)}")
print(f"confusion_matrix=  {confusion_matrix(y_test,y_pred)}")
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0, reg_lambda=0.5; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0, reg_lambda=1; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0.1, reg_lambda=0.5; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=30, reg_alpha=0.1, reg_lambda=0.5; total time=   0.0s
# ...
