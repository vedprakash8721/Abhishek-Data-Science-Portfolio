# %% [markdown]
# Multicollinearity occurs when two or more independent features are highly correlated, meaning they carry overlapping information.
