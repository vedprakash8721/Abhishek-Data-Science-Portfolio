# %% [markdown]
# Day 1 ( 24 feb 26 ):
# Variables are containers that store data.
# Data types define what kind of data is stored (number, text, true/false, etc.).
# Type casting means converting one data type into another.
#
# Python automatically detects data type, but we can also convert it manually.

# %%
a=10.5
b="ved"
c=True
d="10.99"
e="10"
f="5"
print(type(d))
result=float(d)*3
print(result)
print(e+f)
g=int(a)
print(g)
# Out:
# <class 'str'>
# 32.97
# 105
# 10

# %% [markdown]
# Python Basics: Operators + Input/Output
