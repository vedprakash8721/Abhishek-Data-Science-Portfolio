# %%
import pandas as pd 
import numpy as np
data_frame=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# Pandas Advance V3

df1=data_frame[["Name","Age","Sex"]][0:5]
from IPython.display import display
display(df1)
df2=data_frame[["Name","Age","Sex"]][5:10]
display(df2)
print("-------------------------Breaking the line----------------------------\n")

# concatination in data frames
#  there are two types of concatenation . 1: vetical ( rows wise ) 2 : horizontal ( column wise)
display(pd.concat([df1,df2],axis=0)) # axis =0 for rows
display("horizontal concatenation . esse aise samjo ki horizontal way me dataframe increase ho rha hai",pd.concat([df1,df2],axis=1))

# through this both data frames have different value at index so it cause NaN . so if we remove the index from any one of them then it will be resolved
df2.reset_index(drop=True,inplace= True)
display(" Best one ",pd.concat([df1,df2],axis=1))# column wise
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
#                                                 Name   Age     Sex
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                     Palsson, Master. Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# -------------------------Breaking the line----------------------------
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                     Palsson, Master. Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# 'horizontal concatenation . esse aise samjo ki horizontal way me dataframe increase ho rha hai'
#                                                 Name   Age     Sex  \
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                                NaN   NaN     NaN
# 6                                                NaN   NaN     NaN
# 7                                                NaN   NaN     NaN
# 8                                                NaN   NaN     NaN
# 9                                                NaN   NaN     NaN
#
#                                                 Name   Age     Sex
# 0                                                NaN   NaN     NaN
# 1                                                NaN   NaN     NaN
# 2                                                NaN   NaN     NaN
# 3                                                NaN   NaN     NaN
# 4                                                NaN   NaN     NaN
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                     Palsson, Master. Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# ' Best one '
#                                                 Name   Age     Sex  \
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
#
#                                                 Name   Age     Sex
# 0                                   Moran, Mr. James   NaN    male
# 1                            McCarthy, Mr. Timothy J  54.0    male
# 2                     Palsson, Master. Gosta Leonard   2.0    male
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 4                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
""" How to merge two data frames : """
# Pandas Advance V3: 
# generating random data for data frame
import numpy as np
import pandas as pd
data1={
    "key1": [1,45,2,7,44,76,4,9],
    "key2": np.random.randint(1,100,8),
    "key3": np.random.randint(1,100,8)
}
data2={
    "key1": [1,3,4,6,3,5,2,9],
    "key4": np.random.randint(1,100,8),
    "key5": np.random.randint(1,100,8)
}

# data2={
#     "key1": np.random.randint(1,90,8),
#     "key4": np.random.randint(1,100,8),
#     "key5": np.random.randint(1,70,8)
# }

df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
from IPython.display import display
display("this is data frame 1",df1)
print("-------------------------Breaking the line----------------------------\n")
display("this is data frame 2",df2)


# Merge: inner merge ( the common elements will be merged )
display(pd.merge(df1,df2, how='inner')) #  the common element like from key 1 from both df will be print 
print("-------------------------Breaking the line----------------------------\n")
display(pd.merge(df1,df2,how='left')) #all elements of df1 and common elements of key 1 from both will be print 
print("-------------------------Breaking the line----------------------------\n")
display(pd.merge(df1,df2,how='right'))
print("-------------------------Breaking the line----------------------------\n")


# outer merge:
display(pd.merge(df1,df2,how='outer')) # all elements of key1 from both data frame will be present and common elements from key1 will be print

print("-------------------------Breaking the line----------------------------\n")
print(pd.merge(df1,df2,how="cross")) # all the elements will come like first row of key 1 from df1 will merged with all rows of df2 and so on
# Out:
# 'this is data frame 1'
#    key1  key2  key3
# 0     1    64    68
# 1    45    85    63
# 2     2     7    67
# 3     7    52    91
# 4    44    45    88
# 5    76    46     2
# 6     4    91    63
# 7     9    35    39
# -------------------------Breaking the line----------------------------
# 'this is data frame 2'
#    key1  key4  key5
# 0     1    86    23
# 1     3    20    41
# 2     4     6    54
# 3     6    23    57
# 4     3     1    12
# 5     5    16    66
# 6     2     7    19
# 7     9    96    30
#    key1  key2  key3  key4  key5
# 0     1    64    68    86    23
# 1     2     7    67     7    19
# 2     4    91    63     6    54
# 3     9    35    39    96    30
# -------------------------Breaking the line----------------------------
#    key1  key2  key3  key4  key5
# 0     1    64    68  86.0  23.0
# 1    45    85    63   NaN   NaN
# 2     2     7    67   7.0  19.0
# 3     7    52    91   NaN   NaN
# 4    44    45    88   NaN   NaN
# 5    76    46     2   NaN   NaN
# 6     4    91    63   6.0  54.0
# 7     9    35    39  96.0  30.0
# -------------------------Breaking the line----------------------------
#    key1  key2  key3  key4  key5
# 0     1  64.0  68.0    86    23
# 1     3   NaN   NaN    20    41
# 2     4  91.0  63.0     6    54
# 3     6   NaN   NaN    23    57
# 4     3   NaN   NaN     1    12
# 5     5   NaN   NaN    16    66
# 6     2   7.0  67.0     7    19
# 7     9  35.0  39.0    96    30
# -------------------------Breaking the line----------------------------
#     key1  key2  key3  key4  key5
# 0      1  64.0  68.0  86.0  23.0
# 1      2   7.0  67.0   7.0  19.0
# 2      3   NaN   NaN  20.0  41.0
# 3      3   NaN   NaN   1.0  12.0
# 4      4  91.0  63.0   6.0  54.0
# 5      5   NaN   NaN  16.0  66.0
# 6      6   NaN   NaN  23.0  57.0
# 7      7  52.0  91.0   NaN   NaN
# 8      9  35.0  39.0  96.0  30.0
# 9     44  45.0  88.0   NaN   NaN
# 10    45  85.0  63.0   NaN   NaN
# 11    76  46.0   2.0   NaN   NaN
# -------------------------Breaking the line----------------------------
#
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1    64    68       1    86    23
# 1        1    64    68       3    20    41
# 2        1    64    68       4     6    54
# 3        1    64    68       6    23    57
# 4        1    64    68       3     1    12
# ..     ...   ...   ...     ...   ...   ...
# 59       9    35    39       6    23    57
# 60       9    35    39       3     1    12
# 61       9    35    39       5    16    66
# 62       9    35    39       2     7    19
# 63       9    35    39       9    96    30
#
# [64 rows x 6 columns]

# %%
# some advance merge in data frames
display(pd.merge(df1,df2,how='left',left_on="key1",right_on="key4")) # as you can see how="left" then all elements of df1 and according to the condition leff on and right on the common from them will be print
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1    64    68     3.0   1.0  12.0
# 1      45    85    63     NaN   NaN   NaN
# 2       2     7    67     NaN   NaN   NaN
# 3       7    52    91     2.0   7.0  19.0
# 4      44    45    88     NaN   NaN   NaN
# 5      76    46     2     NaN   NaN   NaN
# 6       4    91    63     NaN   NaN   NaN
# 7       9    35    39     NaN   NaN   NaN

# %%
# Pandas Advance V3: 
import numpy as np
# Join
""" difference between join and merge: join works on index and merge works on column
"""
df1=pd.DataFrame({
    "key1": np.random.randint(1,10,6),
    "key2": np.random.randint(1,10,6),
    "key3": np.random.randint(1,10,6)
},index=["a","b","c","d","e","f"]
)

df2=pd.DataFrame({
    "key4": np.random.randint(1,10,6),
    "key5": np.random.randint(1,10,6),
    "key6": np.random.randint(1,10,6)
},index=["a","b","i","d","j","k"]
)

print("-------------------------Breaking the line----------------------------\n")
display(df1)
print("-------------------------Breaking the line----------------------------\n")
display(df2)
print("-------------------------Breaking the line----------------------------\n")

# lets perfom join : inner join
display(df1.join(df2,how="inner")) # this would be syntax :
print("-------------------------Breaking the line----------------------------\n")

# Join: left
display(df1.join(df2,how="left")) # all element of left df and common element from df2 on the basis of index
print("-------------------------Breaking the line----------------------------\n")

# and so on .............
# Out:
# -------------------------Breaking the line----------------------------
#    key1  key2  key3
# a     2     6     2
# b     7     3     1
# c     7     3     6
# d     3     9     2
# e     1     7     5
# f     2     6     8
# -------------------------Breaking the line----------------------------
#    key4  key5  key6
# a     5     7     6
# b     6     5     5
# i     2     7     9
# d     7     8     8
# j     4     8     9
# k     4     9     1
# -------------------------Breaking the line----------------------------
#    key1  key2  key3  key4  key5  key6
# a     2     6     2     5     7     6
# b     7     3     1     6     5     5
# d     3     9     2     7     8     8
# -------------------------Breaking the line----------------------------
#    key1  key2  key3  key4  key5  key6
# a     2     6     2   5.0   7.0   6.0
# b     7     3     1   6.0   5.0   5.0
# c     7     3     6   NaN   NaN   NaN
# d     3     9     2   7.0   8.0   8.0
# e     1     7     5   NaN   NaN   NaN
# f     2     6     8   NaN   NaN   NaN
# -------------------------Breaking the line----------------------------

# %%
# Modification in Data frame:
import pandas as pd 
import numpy as np
data_frame=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

#  so if you want to change the fare column from doller to inr
data_frame["Fare_inr"]=data_frame["Fare"].apply(lambda x:x*90)
 # display(data_frame)


# Use of apply() we can use any function using apply . just place the funtiont that you want to perform
data_frame["name_len"]=data_frame["Name"].apply(len)
display(data_frame)


print("-------------------------Breaking the line----------------------------\n")

# user defined function inside apply function : 
# the same function of the modification of column can be done like this as well

def convert(x):
    return x*90

display(data_frame["Fare"].apply(convert))
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Fare_inr  name_len
# 0        0         A/5 21171   7.2500   NaN        S   652.500        23
# 1        0          PC 17599  71.2833   C85        C  6415.497        51
# 2        0  STON/O2. 3101282   7.9250   NaN        S   713.250        22
# 3        0            113803  53.1000  C123        S  4779.000        44
# 4        0            373450   8.0500   NaN        S   724.500        24
# ..     ...               ...      ...   ...      ...       ...       ...
# 886      0            211536  13.0000   NaN        S  1170.000        21
# 887      0            112053  30.0000   B42        S  2700.000        28
# 888      2        W./C. 6607  23.4500   NaN        S  2110.500        40
# 889      0            111369  30.0000  C148        C  2700.000        21
# 890      0            370376   7.7500   NaN        Q   697.500        19
#
# [891 rows x 14 columns]
# -------------------------Breaking the line----------------------------
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare, Length: 891, dtype: float64

# %%
# some advance operation through user defined function

def category(x):
    if x<10:
        return "Lower class"
    elif x>10 and x<20:
        return "Medium class"
    else:
        return "Upper class"
data_frame["Category"]=data_frame["Fare"].apply(category)
df3=data_frame[["Name","Ticket","Category"]]
display(df3)
# Out:
#                                                   Name            Ticket  \
# 0                              Braund, Mr. Owen Harris         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                               Heikkinen, Miss. Laina  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                             Allen, Mr. William Henry            373450
# ..                                                 ...               ...
# 886                              Montvila, Rev. Juozas            211536
# 887                       Graham, Miss. Margaret Edith            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"        W./C. 6607
# 889                              Behr, Mr. Karl Howell            111369
# 890                                Dooley, Mr. Patrick            370376
#
#          Category
# 0     Lower class
# 1     Upper class
# 2     Lower class
# 3     Upper class
# 4     Lower class
# ..            ...
# 886  Medium class
# 887   Upper class
# 888   Upper class
# 889   Upper class
# 890   Lower class
#
# [891 rows x 3 columns]

# %%
data_frame.reindex(i*2 for i in range(1,len(data_frame["Age"])))

#  iteration row wise:
for i in data_frame.iterrows():
    print(i)


# iteration column wise : 
for i in data_frame.items():
    print(i)
# Out:
# (0, PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Fare_inr                         652.5
# name_len                            23
# Category                   Lower class
# Name: 0, dtype: object)
# (1, PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Fare_inr                                                6415.497
# name_len                                                      51
# Category                                             Upper class
# Name: 1, dtype: object)
# (2, PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Fare_inr                       713.25
# name_len                           22
# Category                  Lower class
# Name: 2, dtype: object)
# (3, PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Fare_inr                                             4779.0
# name_len                                                 44
# Category                                        Upper class
# Name: 3, dtype: object)
# (4, PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Fare_inr                          724.5
# name_len                             24
# Category                    Lower class
# Name: 4, dtype: object)
# (5, PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Fare_inr                761.247
# name_len                     16
# Category            Lower class
# Name: 5, dtype: object)
# (6, PassengerId                          7
# Survived                             0
# Pclass                               1
# Name           McCarthy, Mr. Timothy J
# Sex                               male
# Age                               54.0
# SibSp                                0
# Parch                                0
# Ticket                           17463
# Fare                           51.8625
# Cabin                              E46
# Embarked                             S
# Fare_inr                      4667.625
# name_len                            23
# Category                   Upper class
# Name: 6, dtype: object)
# (7, PassengerId                                 8
# Survived                                    0
# Pclass                                      3
# Name           Palsson, Master. Gosta Leonard
# Sex                                      male
# Age                                       2.0
# SibSp                                       3
# Parch                                       1
# Ticket                                 349909
# Fare                                   21.075
# Cabin                                     NaN
# Embarked                                    S
# Fare_inr                              1896.75
# name_len                                   30
# Category                          Upper class
# Name: 7, dtype: object)
# (8, PassengerId                                                    9
# Survived                                                       1
# Pclass                                                         3
# Name           Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Sex                                                       female
# Age                                                         27.0
# SibSp                                                          0
# Parch                                                          2
# Ticket                                                    347742
# Fare                                                     11.1333
# Cabin                                                        NaN
# Embarked                                                       S
# Fare_inr                                                1001.997
# name_len                                                      49
# Category                                            Medium class
# Name: 8, dtype: object)
# (9, PassengerId                                     10
# Survived                                         1
# Pclass                                           2
# Name           Nasser, Mrs. Nicholas (Adele Achem)
# Sex                                         female
# Age                                           14.0
# SibSp                                            1
# Parch                                            0
# Ticket                                      237736
# Fare                                       30.0708
# Cabin                                          NaN
# Embarked                                         C
# Fare_inr                                  2706.372
# name_len                                        35
# Category                               Upper class
# Name: 9, dtype: object)
# (10, PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# Fare_inr                                1503.0
# name_len                                    31
# Category                          Medium class
# Name: 10, dtype: object)
# (11, PassengerId                          12
# Survived                              1
# Pclass                                1
# Name           Bonnell, Miss. Elizabeth
# Sex                              female
# Age                                58.0
# SibSp                                 0
# Parch                                 0
# Ticket                           113783
# Fare                              26.55
# Cabin                              C103
# Embarked                              S
# Fare_inr                         2389.5
# name_len                             24
# Category                    Upper class
# Name: 11, dtype: object)
# (12, PassengerId                                13
# Survived                                    0
# Pclass                                      3
# Name           Saundercock, Mr. William Henry
# Sex                                      male
# Age                                      20.0
# SibSp                                       0
# Parch                                       0
# Ticket                              A/5. 2151
# Fare                                     8.05
# Cabin                                     NaN
# Embarked                                    S
# Fare_inr                                724.5
# name_len                                   30
# Category                          Lower class
# Name: 12, dtype: object)
# (13, PassengerId                             14
# Survived                                 0
# Pclass                                   3
# Name           Andersson, Mr. Anders Johan
# Sex                                   male
# Age                                   39.0
# SibSp                                    1
# Parch                                    5
# Ticket                              347082
# Fare                                31.275
# Cabin                                  NaN
# Embarked                                 S
# Fare_inr                           2814.75
# name_len                                27
# Category                       Upper class
# Name: 13, dtype: object)
# (14, PassengerId                                      15
# Survived                                          0
# Pclass                                            3
# Name           Vestrom, Miss. Hulda Amanda Adolfina
# Sex                                          female
# Age                                            14.0
# SibSp                                             0
# Parch                                             0
# Ticket                                       350406
# Fare                                         7.8542
# Cabin                                           NaN
# Embarked                                          S
# Fare_inr                                    706.878
# name_len                                         36
# Category                                Lower class
# Name: 14, dtype: object)
# (15, PassengerId                                  16
# Survived                                      1
# Pclass                                        2
# Name           Hewlett, Mrs. (Mary D Kingcome)
# Sex                                      female
# Age                                        55.0
# SibSp                                         0
# Parch                                         0
# Ticket                                   248706
# Fare                                       16.0
# Cabin                                       NaN
# Embarked                                      S
# Fare_inr                                 1440.0
# name_len                                     32
# Category                           Medium class
# Name: 15, dtype: object)
# (16, PassengerId                      17
# Survived                          0
# Pclass                            3
# Name           Rice, Master. Eugene
# Sex                            male
# Age                             2.0
# SibSp                             4
# Parch                             1
# Ticket                       382652
# Fare                         29.125
# Cabin                           NaN
# Embarked                          Q
# Fare_inr                    2621.25
# name_len                         20
# Category                Upper class
# Name: 16, dtype: object)
# (17, PassengerId                              18
# Survived                                  1
# Pclass                                    2
# Name           Williams, Mr. Charles Eugene
# Sex                                    male
# Age                                     NaN
# SibSp                                     0
# Parch                                     0
# Ticket                               244373
# Fare                                   13.0
# Cabin                                   NaN
# Embarked                                  S
# Fare_inr                             1170.0
# name_len                                 28
# Category                       Medium class
# Name: 17, dtype: object)
# (18, PassengerId                                                   19
# Survived                                                       0
# Pclass                                                         3
# Name           Vander Planke, Mrs. Julius (Emelia Maria Vande...
# Sex                                                       female
# Age                                                         31.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                    345763
# Fare                                                        18.0
# Cabin                                                        NaN
# Embarked                                                       S
# Fare_inr                                                  1620.0
# name_len                                                      55
# Category                                            Medium class
# Name: 18, dtype: object)
# (19, PassengerId                         20
# Survived                             1
# Pclass                               3
# Name           Masselmani, Mrs. Fatima
# Sex                             female
# Age                                NaN
# SibSp                                0
# Parch                                0
# Ticket                            2649
# Fare                             7.225
# Cabin                              NaN
# Embarked                             C
# Fare_inr                        650.25
# name_len                            23
# Category                   Lower class
# Name: 19, dtype: object)
# (20, PassengerId                      21
# Survived                          0
# Pclass                            2
# Name           Fynney, Mr. Joseph J
# Sex                            male
# Age                            35.0
# SibSp                             0
# Parch                             0
# Ticket                       239865
# Fare                           26.0
# Cabin                           NaN
# Embarked                          S
# Fare_inr                     2340.0
# name_len                         20
# Category                Upper class
# Name: 20, dtype: object)
# (21, PassengerId                       22
# Survived                           1
# Pclass                             2
# Name           Beesley, Mr. Lawrence
# Sex                             male
# Age                             34.0
# SibSp                              0
# Parch                              0
# Ticket                        248698
# Fare                            13.0
# Cabin                            D56
# Embarked                           S
# Fare_inr                      1170.0
# name_len                          21
# Category                Medium class
# Name: 21, dtype: object)
# (22, PassengerId                             23
# Survived                                 1
# Pclass                                   3
# Name           McGowan, Miss. Anna "Annie"
# Sex                                 female
# Age                                   15.0
# SibSp                                    0
# Parch                                    0
# Ticket                              330923
# Fare                                8.0292
# Cabin                                  NaN
# Embarked                                 Q
# Fare_inr                           722.628
# name_len                                27
# Category                       Lower class
# Name: 22, dtype: object)
# (23, PassengerId                              24
# Survived                                  1
# Pclass                                    1
# Name           Sloper, Mr. William Thompson
# Sex                                    male
# Age                                    28.0
# SibSp                                     0
# Parch                                     0
# Ticket                               113788
# Fare                                   35.5
# Cabin                                    A6
# Embarked                                  S
# Fare_inr                             3195.0
# name_len                                 28
# Category                        Upper class
# Name: 23, dtype: object)
# (24, PassengerId                               25
# Survived                                   0
# Pclass                                     3
# Name           Palsson, Miss. Torborg Danira
# Sex                                   female
# Age                                      8.0
# SibSp                                      3
# Parch                                      1
# Ticket                                349909
# Fare                                  21.075
# Cabin                                    NaN
# Embarked                                   S
# Fare_inr                             1896.75
# name_len                                  29
# Category                         Upper class
# Name: 24, dtype: object)
# (25, PassengerId                                                   26
# Survived                                                       1
# Pclass                                                         3
# Name           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          5
# Ticket                                                    347077
# Fare                                                     31.3875
# Cabin                                                        NaN
# Embarked                                                       S
# Fare_inr                                                2824.875
# name_len                                                      57
# Category                                             Upper class
# Name: 25, dtype: object)
# (26, PassengerId                         27
# Survived                             0
# Pclass                               3
# Name           Emir, Mr. Farred Chehab
# Sex                               male
# Age                                NaN
# SibSp                                0
# Parch                                0
# Ticket                            2631
# Fare                             7.225
# Cabin                              NaN
# Embarked                             C
# Fare_inr                        650.25
# name_len                            23
# Category                   Lower class
# Name: 26, dtype: object)
# (27, PassengerId                                28
# Survived                                    0
# Pclass                                      1
# Name           Fortune, Mr. Charles Alexander
# Sex                                      male
# Age                                      19.0
# SibSp                                       3
# Parch                                       2
# Ticket                                  19950
# Fare                                    263.0
# Cabin                             C23 C25 C27
# Embarked                                    S
# Fare_inr                              23670.0
# name_len                                   30
# Category                          Upper class
# Name: 27, dtype: object)
# (28, PassengerId                               29
# Survived                                   1
# Pclass                                     3
# Name           O'Dwyer, Miss. Ellen "Nellie"
# Sex                                   female
# Age                                      NaN
# SibSp                                      0
# Parch                                      0
# Ticket                                330959
# Fare                                  7.8792
# Cabin                                    NaN
# Embarked                                   Q
# Fare_inr                             709.128
# name_len                                  29
# Category                         Lower class
# Name: 28, dtype: object)
# (29, PassengerId                     30
# Survived                         0
# Pclass                           3
# Name           Todoroff, Mr. Lalio
# Sex                           male
# Age                            NaN
# SibSp                            0
# Parch                            0
# Ticket                      349216
# Fare                        7.8958
# Cabin                          NaN
# Embarked                         S
# Fare_inr                   710.622
# name_len                        19
# Category               Lower class
# Name: 29, dtype: object)
# (30, PassengerId                          31
# Survived                              0
# Pclass                                1
# Name           Uruchurtu, Don. Manuel E
# Sex                                male
# Age                                40.0
# SibSp                                 0
# Parch                                 0
# Ticket                         PC 17601
# Fare                            27.7208
# Cabin                               NaN
# Embarked                              C
# Fare_inr                       2494.872
# name_len                             24
# Category                    Upper class
# Name: 30, dtype: object)
# (31, PassengerId                                                32
# Survived                                                    1
# Pclass                                                      1
# Name           Spencer, Mrs. William Augustus (Marie Eugenie)
# Sex                                                    female
# Age                                                       NaN
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17569
# Fare                                                 146.5208
# Cabin                                                     B78
# Embarked                                                    C
# Fare_inr                                            13186.872
# name_len                                                   46
# Category                                          Upper class
# Name: 31, dtype: object)
# (32, PassengerId                          33
# Survived                              1
# Pclass                                3
# Name           Glynn, Miss. Mary Agatha
# Sex                              female
# Age                                 NaN
# SibSp                                 0
# Parch                                 0
# Ticket                           335677
# Fare                               7.75
# Cabin                               NaN
# Embarked                              Q
# Fare_inr                          697.5
# name_len                             24
# Category                    Lower class
# Name: 32, dtype: object)
# (33, PassengerId                       34
# Survived                           0
# Pclass                             2
# Name           Wheadon, Mr. Edward H
# Sex                             male
# Age                             66.0
# SibSp                              0
# Parch                              0
# Ticket                    C.A. 24579
# Fare                            10.5
# Cabin                            NaN
# Embarked                           S
# Fare_inr                       945.0
# name_len                          21
# Category                Medium class
# Name: 33, dtype: object)
# (34, PassengerId                         35
# Survived                             0
# Pclass                               1
# Name           Meyer, Mr. Edgar Joseph
# Sex                               male
# Age                               28.0
# SibSp                                1
# Parch                                0
# Ticket                        PC 17604
# Fare                           82.1708
# Cabin                              NaN
# Embarked                             C
# Fare_inr                      7395.372
# name_len                            23
# Category                   Upper class
# Name: 34, dtype: object)
# (35, PassengerId                                36
# Survived                                    0
# Pclass                                      1
# Name           Holverson, Mr. Alexander Oskar
# Sex                                      male
# Age                                      42.0
# SibSp                                       1
# Parch                                       0
# Ticket                                 113789
# Fare                                     52.0
# Cabin                                     NaN
# Embarked                                    S
# Fare_inr                               4680.0
# name_len                                   30
# Category                          Upper class
# Name: 35, dtype: object)
# (36, PassengerId                  37
# Survived                      1
# Pclass                        3
# Name           Mamee, Mr. Hanna
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                     2677
# Fare                     7.2292
# Cabin                       NaN
# Embarked                      C
# Fare_inr                650.628
# name_len                     16
# Category            Lower class
# Name: 36, dtype: object)
# (37, PassengerId                          38
# Survived                              0
# Pclass                                3
# Name           Cann, Mr. Ernest Charles
# Sex                                male
# Age                                21.0
# SibSp                                 0
# Parch                                 0
# Ticket                       A./5. 2152
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Fare_inr                          724.5
# name_len                             24
# Category                    Lower class
# Name: 37, dtype: object)
# (38, PassengerId                                    39
# Survived                                        0
# Pclass                                          3
# Name           Vander Planke, Miss. Augusta Maria
# Sex                                        female
# Age                                          18.0
# SibSp                                           2
# Parch                                           0
# Ticket                                     345764
# Fare                                         18.0
# Cabin                                         NaN
# Embarked                                        S
# Fare_inr                                   1620.0
# name_len                                       34
# Category                             Medium class
# Name: 38, dtype: object)
# (39, PassengerId                             40
# Survived                                 1
# Pclass                                   3
# Name           Nicola-Yarred, Miss. Jamila
# Sex                                 female
# Age                                   14.0
# SibSp                                    1
# Parch                                    0
# Ticket                                2651
# Fare                               11.2417
# Cabin                                  NaN
# Embarked                                 C
# Fare_inr                          1011.753
# name_len                                27
# Category                      Medium class
# Name: 39, dtype: object)
# (40, PassengerId                                                41
# Survived                                                    0
# Pclass                                                      3
# Name           Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Sex                                                    female
# Age                                                      40.0
# SibSp                                                       1
# Parch                                                       0
# Ticket                                                   7546
# Fare                                                    9.475
# Cabin                                                     NaN
# Embarked                                                    S
# Fare_inr                                               852.75
# name_len                                                   46
# Category                                          Lower class
# Name: 40, dtype: object)
# (41, PassengerId                                                   42
# Survived                                                       0
# Pclass                                                         2
# Name           Turpin, Mrs. William John Robert (Dorothy Ann ...
# Sex                                                       female
# Age                                                         27.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                     11668
# Fare                                                        21.0
# Cabin                                                        NaN
# Embarked                                                       S
# Fare_inr                                                  1890.0
# name_len                                                      56
# Category                                             Upper class
# Name: 41, dtype: object)
# (42, PassengerId                     43
# Survived                         0
# Pclass                           3
# Name           Kraeff, Mr. Theodor
# Sex                           male
# Age                            NaN
# SibSp                            0
# Parch                            0
# Ticket                      349253
# Fare                        7.8958
# Cabin                          NaN
# Embarked                         C
# Fare_inr                   710.622
# name_len                        19
# Category               Lower class
# Name: 42, dtype: object)
# (43, PassengerId                                          44
# Survived                                              1
# Pclass                                                2
# Name           Laroche, Miss. Simonne Marie Anne Andree
# Sex                                              female
# Age                                                 3.0
# SibSp                                                 1
# Parch                                                 2
# Ticket                                    SC/Paris 2123
# Fare                                            41.5792
# Cabin                                               NaN
# Embarked                                              C
# Fare_inr                                       3742.128
# name_len                                             40
# Category                                    Upper class
# Name: 43, dtype: object)
# (44, PassengerId                               45
# Survived                                   1
# Pclass                                     3
# Name           Devaney, Miss. Margaret Delia
# Sex                                   female
# Age                                     19.0
# SibSp                                      0
# Parch                                      0
# Ticket                                330958
# Fare                                  7.8792
# Cabin                                    NaN
# Embarked                                   Q
# Fare_inr                             709.128
# name_len                                  29
# Category                         Lower class
# Name: 44, dtype: object)
# (45, PassengerId                          46
# Survived                              0
# Pclass                                3
# Name           Rogers, Mr. William John
# Sex                                male
# Age                                 NaN
# SibSp                                 0
# Parch                                 0
# Ticket                  S.C./A.4. 23567
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Fare_inr                          724.5
# name_len                             24
# Category                    Lower class
# Name: 45, dtype: object)
# (46, PassengerId                   47
# Survived                       0
# Pclass                         3
# Name           Lennon, Mr. Denis
# Sex                         male
# Age                          NaN
# SibSp                          1
# Parch                          0
# Ticket                    370371
# Fare                        15.5
# Cabin                        NaN
# Embarked                       Q
# Fare_inr                  1395.0
# name_len                      17
# Category            Medium class
# Name: 46, dtype: object)
# (47, PassengerId                           48
# Survived                               1
# Pclass                                 3
# Name           O'Driscoll, Miss. Bridget
# Sex                               female
# Age                                  NaN
# SibSp                                  0
# Parch                                  0
# Ticket                             14311
# Fare                                7.75
# Cabin                                NaN
# Embarked                               Q
# Fare_inr                           697.5
# name_len                              25
# Category                     Lower class
# Name: 47, dtype: object)
# (48, PassengerId                     49
# Survived                         0
# Pclass                           3
# Name           Samaan, Mr. Youssef
# Sex                           male
# Age                            NaN
# SibSp                            2
# Parch                            0
# Ticket                        2662
# Fare                       21.6792
# Cabin                          NaN
# Embarked                         C
# Fare_inr                  1951.128
# name_len                        19
# Category               Upper class
# Name: 48, dtype: object)
# (49, PassengerId                                               50
# Survived                                                   0
# Pclass                                                     3
# Name           Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# Sex                                                   female
# Age                                                     18.0
# SibSp                                                      1
# Parch                                                      0
# Ticket                                                349237
# Fare                                                    17.8
# Cabin                                                    NaN
# Embarked                                                   S
# Fare_inr                                              1602.0
# name_len                                                  45
# Category                                        Medium class
# Name: 49, dtype: object)
# (50, PassengerId                            51
# Survived                                0
# Pclass                                  3
# Name           Panula, Master. Juha Niilo
# Sex                                  male
# Age                                   7.0
# SibSp                                   4
# Parch                                   1
# Ticket                            3101295
# Fare                              39.6875
# Cabin                                 NaN
# Embarked                                S
# Fare_inr                         3571.875
# name_len                               26
# Category                      Upper class
# Name: 50, dtype: object)
# (51, PassengerId                              52
# Survived                                  0
# Pclass                                    3
# Name           Nosworthy, Mr. Richard Cater
# Sex                                    male
# Age                                    21.0
# SibSp                                     0
# Parch                                     0
# Ticket                           A/4. 39886
# Fare                                    7.8
# Cabin                                   NaN
# Embarked                                  S
# Fare_inr                              702.0
# name_len                                 28
# Category                        Lower class
# Name: 51, dtype: object)
# (52, PassengerId                                          53
# Survived                                              1
# Pclass                                                1
# Name           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Sex                                              female
# Age                                                49.0
# SibSp                                                 1
# Parch                                                 0
# Ticket                                         PC 17572
# Fare                                            76.7292
# Cabin                                               D33
# Embarked                                              C
# Fare_inr                                       6905.628
# name_len                                             40
# Category                                    Upper class
# Name: 52, dtype: object)
# (53, PassengerId                                                   54
# Survived                                                       1
# Pclass                                                         2
# Name           Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...
# Sex                                                       female
# Age                                                         29.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                      2926
# Fare                                                        26.0
# Cabin                                                        NaN
# Embarked                                                       S
# Fare_inr                                                  2340.0
# name_len                                                      50
# Category                                             Upper class
# Name: 53, dtype: object)
# (54, PassengerId                                55
# Survived                                    0
# Pclass                                      1
# Name           Ostby, Mr. Engelhart Cornelius
# Sex                                      male
# Age                                      65.0
# SibSp                                       0
# Parch                                       1
# Ticket                                 113509
# Fare                                  61.9792
# Cabin                                     B30
# Embarked                                    C
# Fare_inr                             5578.128
# name_len                                   30
# Category                          Upper class
# Name: 54, dtype: object)
# (55, PassengerId                   56
# Survived                       1
# Pclass                         1
# Name           Woolner, Mr. Hugh
# Sex                         male
# Age                          NaN
# SibSp                          0
# Parch                          0
# Ticket                     19947
# Fare                        35.5
# Cabin                        C52
# Embarked                       S
# Fare_inr                  3195.0
# name_len                      17
# Category             Upper class
# Name: 55, dtype: object)
# (56, PassengerId                   57
# Survived                       1
# Pclass                         2
# Name           Rugg, Miss. Emily
# Sex                       female
# Age                         21.0
# SibSp                          0
# Parch                          0
# Ticket                C.A. 31026
# Fare                        10.5
# Cabin                        NaN
# Embarked                       S
# Fare_inr                   945.0
# name_len                      17
# Category            Medium class
# Name: 56, dtype: object)
# (57, PassengerId                     58
# Survived                         0
# Pclass                           3
# Name           Novel, Mr. Mansouer
# Sex                           male
# Age                           28.5
# SibSp                            0
# Parch                            0
# Ticket                        2697
# Fare                        7.2292
# Cabin                          NaN
# Embarked                         C
# Fare_inr                   650.628
# name_len                        19
# Category               Lower class
# Name: 57, dtype: object)
# (58, PassengerId                              59
# Survived                                  1
# Pclass                                    2
# Name           West, Miss. Constance Mirium
# Sex                                  female
# Age                                     5.0
# SibSp                                     1
# Parch                                     2
# Ticket                           C.A. 34651
# Fare                                  27.75
# Cabin                                   NaN
# Embarked                                  S
# Fare_inr                             2497.5
# name_len                                 28
# Category                        Upper class
# Name: 58, dtype: object)
# (59, PassengerId                                    60
# Survived                                        0
# Pclass                                          3
# Name           Goodwin, Master. William Frederick
# Sex                                          male
# Age                                          11.0
# SibSp                                           5
# Parch                                           2
# Ticket                                    CA 2144
# Fare                                         46.9
# Cabin                                         NaN
# Embarked                                        S
# Fare_inr                                   4221.0
# name_len                                       34
# Category                              Upper class
# Name: 59, dtype: object)
# (60, PassengerId                       61
# Survived                           0
# Pclass                             3
# Name           Sirayanian, Mr. Orsen
# Sex                             male
# Age                             22.0
# SibSp                              0
# Parch                              0
# Ticket                          2669
# Fare                          7.2292
# Cabin                            NaN
# Embarked                           C
# Fare_inr                     650.628
# name_len                          21
# Category                 Lower class
# Name: 60, dtype: object)
# (61, PassengerId                     62
# Survived                         1
# Pclass                           1
# Name           Icard, Miss. Amelie
# Sex                         female
# Age                           38.0
# SibSp                            0
# Parch                            0
# Ticket                      113572
# Fare                          80.0
# Cabin                          B28
# Embarked                       NaN
# Fare_inr                    7200.0
# name_len                        19
# Category               Upper class
# Name: 61, dtype: object)
# (62, PassengerId                             63
# Survived                                 0
# Pclass                                   1
# Name           Harris, Mr. Henry Birkhardt
# Sex                                   male
# Age                                   45.0
# SibSp                                    1
# Parch                                    0
# Ticket                               36973
# Fare                                83.475
# Cabin                                  C83
# Embarked                                 S
# Fare_inr                           7512.75
# name_len                                27
# Category                       Upper class
# Name: 62, dtype: object)
# (63, PassengerId                       64
# Survived                           0
# Pclass                             3
# Name           Skoog, Master. Harald
# Sex                             male
# Age                              4.0
# SibSp                              3
# Parch                              2
# Ticket                        347088
# Fare                            27.9
# Cabin                            NaN
# Embarked                           S
# Fare_inr                      2511.0
# name_len                          21
# Category                 Upper class
# Name: 63, dtype: object)
# (64, PassengerId                       65
# Survived                           0
# Pclass                             1
# Name           Stewart, Mr. Albert A
# Sex                             male
# Age                              NaN
# SibSp                              0
# Parch                              0
# Ticket                      PC 17605
# Fare                         27.7208
# Cabin                            NaN
# Embarked                           C
# Fare_inr                    2494.872
# name_len                          21
# Category                 Upper class
# Name: 64, dtype: object)
# (65, PassengerId                          66
# Survived                              1
# Pclass                                3
# Name           Moubarek, Master. Gerios
# Sex                                male
# Age                                 NaN
# SibSp                                 1
# Parch                                 1
# Ticket                             2661
# Fare                            15.2458
# Cabin                               NaN
# Embarked                              C
# Fare_inr                       1372.122
# name_len                             24
# Category                   Medium class
# Name: 65, dtype: object)
# (66, PassengerId                              67
# Survived                                  1
# Pclass                                    2
# Name           Nye, Mrs. (Elizabeth Ramell)
# Sex                                  female
# Age                                    29.0
# SibSp                                     0
# Parch                                     0
# Ticket                           C.A. 29395
# Fare                                   10.5
# Cabin                                   F33
# Embarked                                  S
# Fare_inr                              945.0
# name_len                                 28
# Category                       Medium class
# Name: 66, dtype: object)
# (67, PassengerId                          68
# Survived                              0
# Pclass                                3
# Name           Crease, Mr. Ernest James
# Sex                                male
# Age                                19.0
# SibSp                                 0
# Parch                                 0
# Ticket                        S.P. 3464
# Fare                             8.1583
# Cabin                               NaN
# Embarked                              S
# Fare_inr                        734.247
# name_len                             24
# Category                    Lower class
# Name: 67, dtype: object)
# (68, PassengerId                                 69
# Survived                                     1
# Pclass                                       3
# Name           Andersson, Miss. Erna Alexandra
# Sex                                     female
# Age                                       17.0
# SibSp                                        4
# Parch                                        2
# Ticket                                 3101281
# Fare                                     7.925
# ...
# (873, PassengerId                            874
# Survived                                 0
# Pclass                                   3
# Name           Vander Cruyssen, Mr. Victor
# Sex                                   male
# Age                                   47.0
# SibSp                                    0
# Parch                                    0
# Ticket                              345765
# Fare                                   9.0
# Cabin                                  NaN
# Embarked                                 S
# Fare_inr                             810.0
# name_len                                27
# Category                       Lower class
# Name: 873, dtype: object)
# (874, PassengerId                                      875
# Survived                                           1
# Pclass                                             2
# Name           Abelson, Mrs. Samuel (Hannah Wizosky)
# Sex                                           female
# Age                                             28.0
# SibSp                                              1
# Parch                                              0
# Ticket                                     P/PP 3381
# Fare                                            24.0
# Cabin                                            NaN
# Embarked                                           C
# Fare_inr                                      2160.0
# name_len                                          37
# Category                                 Upper class
# Name: 874, dtype: object)
# (875, PassengerId                                 876
# Survived                                      1
# Pclass                                        3
# Name           Najib, Miss. Adele Kiamie "Jane"
# Sex                                      female
# Age                                        15.0
# SibSp                                         0
# Parch                                         0
# Ticket                                     2667
# Fare                                      7.225
# Cabin                                       NaN
# Embarked                                      C
# Fare_inr                                 650.25
# name_len                                     32
# Category                            Lower class
# Name: 875, dtype: object)
# (876, PassengerId                              877
# Survived                                   0
# Pclass                                     3
# Name           Gustafsson, Mr. Alfred Ossian
# Sex                                     male
# Age                                     20.0
# SibSp                                      0
# Parch                                      0
# Ticket                                  7534
# Fare                                  9.8458
# Cabin                                    NaN
# Embarked                                   S
# Fare_inr                             886.122
# name_len                                  29
# Category                         Lower class
# Name: 876, dtype: object)
# (877, PassengerId                     878
# Survived                          0
# Pclass                            3
# Name           Petroff, Mr. Nedelio
# Sex                            male
# Age                            19.0
# SibSp                             0
# Parch                             0
# Ticket                       349212
# Fare                         7.8958
# Cabin                           NaN
# Embarked                          S
# Fare_inr                    710.622
# name_len                         20
# Category                Lower class
# Name: 877, dtype: object)
# (878, PassengerId                   879
# Survived                        0
# Pclass                          3
# Name           Laleff, Mr. Kristo
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Ticket                     349217
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Fare_inr                  710.622
# name_len                       18
# Category              Lower class
# Name: 878, dtype: object)
# (879, PassengerId                                              880
# Survived                                                   1
# Pclass                                                     1
# Name           Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# Sex                                                   female
# Age                                                     56.0
# SibSp                                                      0
# Parch                                                      1
# Ticket                                                 11767
# Fare                                                 83.1583
# Cabin                                                    C50
# Embarked                                                   C
# Fare_inr                                            7484.247
# name_len                                                  45
# Category                                         Upper class
# Name: 879, dtype: object)
# (880, PassengerId                                             881
# Survived                                                  1
# Pclass                                                    2
# Name           Shelley, Mrs. William (Imanita Parrish Hall)
# Sex                                                  female
# Age                                                    25.0
# SibSp                                                     0
# Parch                                                     1
# Ticket                                               230433
# Fare                                                   26.0
# Cabin                                                   NaN
# Embarked                                                  S
# Fare_inr                                             2340.0
# name_len                                                 44
# Category                                        Upper class
# Name: 880, dtype: object)
# (881, PassengerId                   882
# Survived                        0
# Pclass                          3
# Name           Markun, Mr. Johann
# Sex                          male
# Age                          33.0
# SibSp                           0
# Parch                           0
# Ticket                     349257
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Fare_inr                  710.622
# name_len                       18
# Category              Lower class
# Name: 881, dtype: object)
# (882, PassengerId                             883
# Survived                                  0
# Pclass                                    3
# Name           Dahlberg, Miss. Gerda Ulrika
# Sex                                  female
# Age                                    22.0
# SibSp                                     0
# Parch                                     0
# Ticket                                 7552
# Fare                                10.5167
# Cabin                                   NaN
# Embarked                                  S
# Fare_inr                            946.503
# name_len                                 28
# Category                       Medium class
# Name: 882, dtype: object)
# (883, PassengerId                              884
# Survived                                   0
# Pclass                                     2
# Name           Banfield, Mr. Frederick James
# Sex                                     male
# Age                                     28.0
# SibSp                                      0
# Parch                                      0
# Ticket                      C.A./SOTON 34068
# Fare                                    10.5
# Cabin                                    NaN
# Embarked                                   S
# Fare_inr                               945.0
# name_len                                  29
# Category                        Medium class
# Name: 883, dtype: object)
# (884, PassengerId                       885
# Survived                            0
# Pclass                              3
# Name           Sutehall, Mr. Henry Jr
# Sex                              male
# Age                              25.0
# SibSp                               0
# Parch                               0
# Ticket                SOTON/OQ 392076
# Fare                             7.05
# Cabin                             NaN
# Embarked                            S
# Fare_inr                        634.5
# name_len                           22
# Category                  Lower class
# Name: 884, dtype: object)
# (885, PassengerId                                     886
# Survived                                          0
# Pclass                                            3
# Name           Rice, Mrs. William (Margaret Norton)
# Sex                                          female
# Age                                            39.0
# SibSp                                             0
# Parch                                             5
# Ticket                                       382652
# Fare                                         29.125
# Cabin                                           NaN
# Embarked                                          Q
# Fare_inr                                    2621.25
# name_len                                         36
# Category                                Upper class
# Name: 885, dtype: object)
# (886, PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# Fare_inr                      1170.0
# name_len                          21
# Category                Medium class
# Name: 886, dtype: object)
# (887, PassengerId                             888
# Survived                                  1
# Pclass                                    1
# Name           Graham, Miss. Margaret Edith
# Sex                                  female
# Age                                    19.0
# SibSp                                     0
# Parch                                     0
# Ticket                               112053
# Fare                                   30.0
# Cabin                                   B42
# Embarked                                  S
# Fare_inr                             2700.0
# name_len                                 28
# Category                        Upper class
# Name: 887, dtype: object)
# (888, PassengerId                                         889
# Survived                                              0
# Pclass                                                3
# Name           Johnston, Miss. Catherine Helen "Carrie"
# Sex                                              female
# Age                                                 NaN
# SibSp                                                 1
# Parch                                                 2
# Ticket                                       W./C. 6607
# Fare                                              23.45
# Cabin                                               NaN
# Embarked                                              S
# Fare_inr                                         2110.5
# name_len                                             40
# Category                                    Upper class
# Name: 888, dtype: object)
# (889, PassengerId                      890
# Survived                           1
# Pclass                             1
# Name           Behr, Mr. Karl Howell
# Sex                             male
# Age                             26.0
# SibSp                              0
# Parch                              0
# Ticket                        111369
# Fare                            30.0
# Cabin                           C148
# Embarked                           C
# Fare_inr                      2700.0
# name_len                          21
# Category                 Upper class
# Name: 889, dtype: object)
# (890, PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Fare_inr                     697.5
# name_len                        19
# Category               Lower class
# Name: 890, dtype: object)
# ('PassengerId', 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64)
# ('Survived', 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64)
# ('Pclass', 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64)
# ('Name', 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object)
# ('Sex', 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object)
# ('Age', 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64)
# ('SibSp', 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64)
# ('Parch', 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64)
# ('Ticket', 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object)
# ('Fare', 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64)
# ('Cabin', 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object)
# ('Embarked', 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object)
# ('Fare_inr', 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare_inr, Length: 891, dtype: float64)
# ('name_len', 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: name_len, Length: 891, dtype: int64)
# ('Category', 0       Lower class
# 1       Upper class
# 2       Lower class
# 3       Upper class
# 4       Lower class
#            ...
# 886    Medium class
# 887     Upper class
# 888     Upper class
# 889     Upper class
# 890     Lower class
# Name: Category, Length: 891, dtype: object)
